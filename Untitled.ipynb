# %%
import pandas as pd

# %%
from numpy import NaN, NAN, nan

# %%
import matplotlib
# %matplotlib inline

# %%
marrakai0816 = pd.read_excel('../Land_Use/08-16_change_over_time_EDIT.xlsx')

# %%
marrakai0816.head()
# Out:
#    LU_CODE_08  08_AREA  LU_CODE_16  COMMOD       16_AREA
# 0           0      0.0         652          1.370713e+06
# 1           0      0.0         210  cattle  1.158460e+07
# 2           0      0.0         652          1.427609e+05
# 3           0      0.0         113          3.356297e+04
# 4           0      0.0         652          7.526508e+05

# %%
marrakai0816.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 795 entries, 0 to 794
# Data columns (total 5 columns):
# LU_CODE_08    795 non-null int64
# 08_AREA       795 non-null float64
# LU_CODE_16    795 non-null int64
# COMMOD        795 non-null object
# 16_AREA       795 non-null float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 31.1+ KB

# %%
marrakai0816.describe()
# Out:
#        LU_CODE_08        08_AREA  LU_CODE_16       16_AREA
# count  795.000000     795.000000  795.000000  7.950000e+02
# mean   114.540881   24570.541706  476.396226  4.201152e+05
# std    194.464411   56000.199188  104.255959  1.771465e+06
# min      0.000000       0.000000  113.000000  2.154370e+02
# 25%      0.000000       0.000000  453.000000  1.212597e+04
# 50%      0.000000       0.000000  512.000000  3.123038e+04
# 75%    440.000000   12745.953220  543.000000  8.152916e+04
# max    460.000000  254160.997997  654.000000  1.865889e+07

# %%
marrakai0816.groupby('LU_CODE_08')['08_AREA'].sum()
# Out:
# LU_CODE_08
# 0      0.000000e+00
# 440    3.216970e+06
# 441    8.629583e+06
# 450    4.249394e+06
# 460    3.437634e+06
# Name: 08_AREA, dtype: float64

# %%
test = marrakai0816.groupby(['LU_CODE_16'])['16_AREA'].sum()

# %%
test.head()
# Out:
# LU_CODE_16
# 113    2.115370e+07
# 125    1.500568e+07
# 133    2.242812e+07
# 210    1.421016e+08
# 320    2.349640e+06
# Name: 16_AREA, dtype: float64

# %%
df = marrakai0816.groupby(['LU_CODE_08', 'LU_CODE_16'])['16_AREA'].sum()

# %%
test2.head()
# Out:
# LU_CODE_08  LU_CODE_16
# 0           113           2.115370e+07
#             125           1.500568e+07
#             133           1.236465e+07
#             210           1.156794e+08
#             320           1.612920e+06
# Name: 16_AREA, dtype: float64

# %%
test2.iloc[1]
# Out:
# 15005684.999676179

# %%
marrakai081.groupby(['LU_CODE_08', 'LU_CODE_16'])['08_AREA'].mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-82-710590acf61c> in <module>()
# ----> 1 marrakai081.groupby(['LU_CODE_08', 'LU_CODE_16'])['08_AREA'].mean()
#
# NameError: name 'marrakai081' is not defined

# %%
df=pd.read_excel('../Land_Use/08-16_change_over_time_EDIT.xlsx')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 795 entries, 0 to 794
# Data columns (total 5 columns):
# LU_CODE_08    795 non-null int64
# 08_AREA       795 non-null float64
# LU_CODE_16    795 non-null int64
# COMMOD        795 non-null object
# 16_AREA       795 non-null float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 31.1+ KB

# %%
df = pd.read_excel('../Land_Use/Final_08-16_change_over_time.xlsx')

# %%
df.head()
# Out:
#    LU_CODE_08  08_AREA  LU_CODE_16  COMMOD      16_AREA
# 0           0      0.0         652           1370712.55
# 1           0      0.0         210  cattle  11584595.65
# 2           0      0.0         652            142760.94
# 3           0      0.0         113             33562.97
# 4           0      0.0         652            752650.83

# %%
marrakai0816.head(5)
# Out:
#    LU_CODE_08  08_AREA  LU_CODE_16  COMMOD       16_AREA
# 0           0      0.0         652          1.370713e+06
# 1           0      0.0         210  cattle  1.158460e+07
# 2           0      0.0         652          1.427609e+05
# 3           0      0.0         113          3.356297e+04
# 4           0      0.0         652          7.526508e+05

# %%
marrakai0816.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147 entries, 0 to 146
# Data columns (total 11 columns):
# codes               5 non-null object
# description         4 non-null object
# Property            34 non-null object
# Property Area m2    0 non-null float64
# commodity           0 non-null float64
# Isolated m2         35 non-null float64
# codes.1             146 non-null float64
# description.1       147 non-null object
# Total m2            123 non-null float64
# commodity.1         75 non-null object
# Commodity m2        75 non-null float64
# dtypes: float64(6), object(5)
# memory usage: 12.7+ KB

# %%
df.fillna({'codes': NaN, 'description': NaN})
# Out:
#      codes                       description       Property  Property Area m2  \
# 0        0                               NaN            NaN               NaN
# 1      NaN                               NaN            NaN               NaN
# 2      NaN                               NaN            NaN               NaN
# 3      NaN                               NaN            NaN               NaN
# 4      NaN                               NaN            NaN               NaN
# 5      NaN                               NaN            NaN               NaN
# 6      NaN                               NaN            NaN               NaN
# 7      NaN                               NaN            NaN               NaN
# 8      NaN                               NaN            NaN               NaN
# 9      NaN                               NaN            NaN               NaN
# 10     NaN                               NaN            NaN               NaN
# ...

# %%
df
# Out:
#      codes                       description       Property  Property Area m2  \
# 0        0                               NaN            NaN               NaN
# 1      NaN                               NaN            NaN               NaN
# 2      NaN                               NaN            NaN               NaN
# 3      NaN                               NaN            NaN               NaN
# 4      NaN                               NaN            NaN               NaN
# 5      NaN                               NaN            NaN               NaN
# 6      NaN                               NaN            NaN               NaN
# 7      NaN                               NaN            NaN               NaN
# 8      NaN                               NaN            NaN               NaN
# 9      NaN                               NaN            NaN               NaN
# 10     NaN                               NaN            NaN               NaN
# ...
