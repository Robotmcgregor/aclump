# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df= pd.read_excel('../Land_Use/16-08_change_over_time_EDIT.xlsx')

# %%
df.head()
# Out:
#    LU_CODE_16 LU_CODE LU_DESCRIP COMMOD_DES COMMENTS SRCE_SCALE  SRCE_DATE  \
# 0           0     NaN        NaN        NaN      NaN        NaN          0
# 1           0     NaN        NaN        NaN      NaN        NaN          0
# 2           0     NaN        NaN        NaN      NaN        NaN          0
# 3           0     NaN        NaN        NaN      NaN        NaN          0
# 4           0     NaN        NaN        NaN      NaN        NaN          0
#
#   SRCE_DATA  CONFIDENCE  LUC_DATE      ...       SRC_DATE RELIABLE  \
# 0       NaN           0         0      ...          38168        3
# 1       NaN           0         0      ...          38168        3
# 2       NaN           0         0      ...          39219        2
# 3       NaN           0         0      ...          39219        2
# 4       NaN           0         0      ...          38168        3
#
#    LUC_DATE_1 LU_CODE_08  CLASS_NO  \
# 0       39591        572         5
# 1       39591        210         2
# ...

# %%
#change 08 and 16 to strings
df['CODE_08'] = df['LU_CODE_08'].astype(str)
df['CODE_16'] = df['LU_CODE_16'].astype(str)

# %%
# make the new columns for LU08 using string indexing
df['prim_08'] = df['CODE_08'].str[0:1]
df['secon_08'] = df['CODE_08'].str[:2]
df['third_08'] = df['CODE_08'].str[0:3]
# make the new columns for LU16 using string indexing
df['prim_16'] = df['CODE_16'].str[0:1]
df['secon_16'] = df['CODE_16'].str[:2]
df['third_16'] = df['CODE_16'].str[0:3]

# %%
df.head()
# Out:
#    LU_CODE_16 LU_CODE LU_DESCRIP COMMOD_DES COMMENTS SRCE_SCALE  SRCE_DATE  \
# 0           0     NaN        NaN        NaN      NaN        NaN          0
# 1           0     NaN        NaN        NaN      NaN        NaN          0
# 2           0     NaN        NaN        NaN      NaN        NaN          0
# 3           0     NaN        NaN        NaN      NaN        NaN          0
# 4           0     NaN        NaN        NaN      NaN        NaN          0
#
#   SRCE_DATA  CONFIDENCE  LUC_DATE    ...     Shape_Length    Shape_Area  \
# 0       NaN           0         0    ...     97282.049314  4.599524e+06
# 1       NaN           0         0    ...     21949.027528  1.346029e+07
# 2       NaN           0         0    ...      8905.356723  2.500118e+06
# 3       NaN           0         0    ...     50683.895175  2.261812e+07
# 4       NaN           0         0    ...     12756.550434  8.466834e+06
#
#    CODE_08 CODE_16  prim_08  secon_08  third_08  prim_16  secon_16  third_16
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 713 entries, 0 to 712
# Data columns (total 43 columns):
# LU_CODE_16                    713 non-null int64
# LU_CODE                       385 non-null object
# LU_DESCRIP                    385 non-null object
# COMMOD_DES                    385 non-null object
# COMMENTS                      385 non-null object
# SRCE_SCALE                    385 non-null object
# SRCE_DATE                     713 non-null int64
# SRCE_DATA                     385 non-null object
# CONFIDENCE                    713 non-null int64
# LUC_DATE                      713 non-null int64
# PRIM_NO                       713 non-null int64
# PRIM_DESC                     385 non-null object
# SEC_NO                        713 non-null int64
# SEC_DESC                      385 non-null object
# AREA_HA                       713 non-null float64
# SHAPE_Leng                    713 non-null float64
# PERIM_M                       713 non-null float64
# ...

# %%
df20 = df[['secon_08', '08_AREA']]
df20
# Out:
#     secon_08       08_AREA
# 0         57  4.599525e+06
# 1         21  1.346029e+07
# 2         11  2.500118e+06
# 3         11  2.261812e+07
# 4         33  8.466834e+06
# 5         21  2.285065e+06
# 6         56  9.602834e+02
# 7         12  2.289862e+07
# 8         21  1.649997e+05
# 9         21  1.006345e+07
# 10        65  1.013193e+06
# 11        11  3.030497e+05
# 12        13  6.577069e+04
# 13        45  2.242319e+05
# 14        13  4.167762e+04
# 15        13  1.706269e+05
# 16        13  1.102906e+05
# 17        44  8.133198e+04
# 18        36  1.471917e+05
# 19        13  6.148589e+04
# 20        13  1.052641e+05
# 21        54  9.045701e+04
# 22        54  6.013787e+04
# 23        36  1.943502e+05
# 24        54  8.566494e+04
# 25        21  8.483079e+06
# 26        13  6.008675e+04
# 27        54  8.870736e+04
# 28        13  6.220724e+04
# 29        36  1.249749e+05
# ..       ...           ...
# 683       54  1.939517e+04
# 684       44  5.518480e+04
# ...

# %%
df1 = df[['secon_16', '16_AREA']]
df1
# Out:
#     secon_16        16_AREA
# 0          0       0.000000
# 1          0       0.000000
# 2          0       0.000000
# 3          0       0.000000
# 4          0       0.000000
# 5          0       0.000000
# 6          0       0.000000
# 7          0       0.000000
# 8          0       0.000000
# 9          0       0.000000
# 10         0       0.000000
# 11         0       0.000000
# 12         0       0.000000
# 13         0       0.000000
# 14         0       0.000000
# 15         0       0.000000
# 16         0       0.000000
# 17         0       0.000000
# 18         0       0.000000
# 19         0       0.000000
# 20         0       0.000000
# 21         0       0.000000
# 22         0       0.000000
# 23         0       0.000000
# 24         0       0.000000
# 25         0       0.000000
# 26         0       0.000000
# 27         0       0.000000
# 28         0       0.000000
# 29         0       0.000000
# ..       ...            ...
# 683       44   12455.934898
# ...

# %%
df20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 713 entries, 0 to 712
# Data columns (total 2 columns):
# secon_08    713 non-null object
# 08_AREA     713 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 11.2+ KB

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 713 entries, 0 to 712
# Data columns (total 2 columns):
# secon_16    713 non-null object
# 16_AREA     713 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 11.2+ KB

# %%
import numpy as np
#First irrigated value
df1 = df.groupby(['secon_16']).agg({'16_AREA':np.sum})
#Second irrigated valuu
df20 = df.groupby(['secon_08']).agg({'08_AREA':np.sum})

# %%
df1
# Out:
#                16_AREA
# secon_16
# 0         0.000000e+00
# 44        2.766366e+06
# 45        3.068234e+06
# 46        1.617114e+06
# 51        1.081492e+05

# %%
df20
# Out:
#                08_AREA
# secon_08
# 11        2.543410e+07
# 12        2.289862e+07
# 13        3.357311e+08
# 21        6.781594e+07
# 32        3.443423e+05
# 33        8.466834e+06
# 36        1.305650e+07
# 44        8.933333e+06
# 45        3.383833e+06
# 46        2.084482e+06
# 52        9.484829e+03
# 54        1.307634e+07
# 55        5.256832e+04
# 56        9.602834e+02
# 57        3.303606e+07
# 62        1.038775e+04
# 65        1.013193e+06

# %%
df20 = df.drop(['11', '12'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-28b10c94d98a> in <module>()
# ----> 1 df20 = df.drop(['11', '12'])
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, level, inplace, errors)
#    2159                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2160             else:
# -> 2161                 new_axis = axis.drop(labels, errors=errors)
#    2162             dropped = self.reindex(**{axis_name: new_axis})
#    2163             try:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    3622             if errors != 'ignore':
#    3623                 raise ValueError('labels %s not contained in axis' %
# -> 3624                                  labels[mask])
#    3625             indexer = indexer[~mask]
# ...

# %%
df20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17 entries, 11 to 65
# Data columns (total 1 columns):
# 08_AREA    17 non-null float64
# dtypes: float64(1)
# memory usage: 272.0+ bytes

# %%
df20
# Out:
#                08_AREA
# secon_08
# 11        2.543410e+07
# 12        2.289862e+07
# 13        3.357311e+08
# 21        6.781594e+07
# 32        3.443423e+05
# 33        8.466834e+06
# 36        1.305650e+07
# 44        8.933333e+06
# 45        3.383833e+06
# 46        2.084482e+06
# 52        9.484829e+03
# 54        1.307634e+07
# 55        5.256832e+04
# 56        9.602834e+02
# 57        3.303606e+07
# 62        1.038775e+04
# 65        1.013193e+06

# %%
#change 08 and 16 to intigers

df1['secon_16'] = df['seconint_16'].astype(int)
df20['secon_08'] = df['seconint_08'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'seconint_16'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-2f6befc5b0c6> in <module>()
# ...

# %% [markdown]
# # This is the issue - 0 non null values???

# %%
df21 = df20[df20['secon_08'] >39]
df22 = df21[df21['secon_08'] <52]

# %%
df1.info()
df20.info()

# %%
df20

# %%
df22.info()

# %%
df22

# %%
df20

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Plot the first value
x1 = df['seconstring_08']
y1 = df ['08_AREA']
plt.bar(x1, y1)
plt.xlabel('Land use')
plt.ylabel('Area')

# %%
#Plot the second value
x2 = df['secon_16']
y2 = df ['16_AREA']
plt.bar(x2, y2)
plt.xlabel('Land use')
plt.ylabel('Area')

# %%
import numpy as np
import matplotlib.pyplot as plt
 
# data to plot

means_frank = df['08_AREA']
means_guido = df['16_AREA']
 
# create plot
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.35
opacity = 0.8
 
rects1 = plt.bar(index, means_frank, bar_width,
                 alpha=opacity,
                 color='b',
                 label='2008')
 
rects2 = plt.bar(index + bar_width, means_guido, bar_width,
                 alpha=opacity,
                 color='g',
                 label='2016')
 
plt.xlabel('Land use')
plt.ylabel('Area')
plt.title('Scores by person')
plt.xticks(index + bar_width, ('A', 'B', 'C', 'D'))
plt.legend()
     
plt.tight_layout()
plt.show()
