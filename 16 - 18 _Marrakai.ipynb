# %%
import pandas as pd

# %%
from numpy import NaN, NAN, nan

# %%
import matplotlib as plt
# %matplotlib inline

# %%
df= pd.read_excel('../Land_Use/16-08_change_over_time_EDIT.xlsx')

# %%
df.head()
# Out:
#    LU_CODE_16 LU_CODE LU_DESCRIP COMMOD_DES COMMENTS SRCE_SCALE  SRCE_DATE  \
# 0           0     NaN        NaN        NaN      NaN        NaN          0
# 1           0     NaN        NaN        NaN      NaN        NaN          0
# 2           0     NaN        NaN        NaN      NaN        NaN          0
# 3           0     NaN        NaN        NaN      NaN        NaN          0
# 4           0     NaN        NaN        NaN      NaN        NaN          0
#
#   SRCE_DATA  CONFIDENCE  LUC_DATE      ...       SRC_DATE RELIABLE  \
# 0       NaN           0         0      ...          38168        3
# 1       NaN           0         0      ...          38168        3
# 2       NaN           0         0      ...          39219        2
# 3       NaN           0         0      ...          39219        2
# 4       NaN           0         0      ...          38168        3
#
#    LUC_DATE_1 LU_CODE_08  CLASS_NO  \
# 0       39591        572         5
# 1       39591        210         2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 713 entries, 0 to 712
# Data columns (total 35 columns):
# LU_CODE_16                    713 non-null int64
# LU_CODE                       385 non-null object
# LU_DESCRIP                    385 non-null object
# COMMOD_DES                    385 non-null object
# COMMENTS                      385 non-null object
# SRCE_SCALE                    385 non-null object
# SRCE_DATE                     713 non-null int64
# SRCE_DATA                     385 non-null object
# CONFIDENCE                    713 non-null int64
# LUC_DATE                      713 non-null int64
# PRIM_NO                       713 non-null int64
# PRIM_DESC                     385 non-null object
# SEC_NO                        713 non-null int64
# SEC_DESC                      385 non-null object
# AREA_HA                       713 non-null float64
# SHAPE_Leng                    713 non-null float64
# PERIM_M                       713 non-null float64
# ...

# %%
df
# Out:
#      LU_CODE_16 LU_CODE             LU_DESCRIP COMMOD_DES  \
# 0             0     NaN                    NaN        NaN
# 1             0     NaN                    NaN        NaN
# 2             0     NaN                    NaN        NaN
# 3             0     NaN                    NaN        NaN
# 4             0     NaN                    NaN        NaN
# 5             0     NaN                    NaN        NaN
# 6             0     NaN                    NaN        NaN
# 7             0     NaN                    NaN        NaN
# 8             0     NaN                    NaN        NaN
# 9             0     NaN                    NaN        NaN
# 10            0     NaN                    NaN        NaN
# 11            0     NaN                    NaN        NaN
# 12            0     NaN                    NaN        NaN
# 13            0     NaN                    NaN        NaN
# 14            0     NaN                    NaN        NaN
# ...

# %%
#change 08 and 16 to strings
df['CODE_08'] = df['LU_CODE_08'].astype(str)
df['CODE_16'] = df['LU_CODE_16'].astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 713 entries, 0 to 712
# Data columns (total 37 columns):
# LU_CODE_16                    713 non-null int64
# LU_CODE                       385 non-null object
# LU_DESCRIP                    385 non-null object
# COMMOD_DES                    385 non-null object
# COMMENTS                      385 non-null object
# SRCE_SCALE                    385 non-null object
# SRCE_DATE                     713 non-null int64
# SRCE_DATA                     385 non-null object
# CONFIDENCE                    713 non-null int64
# LUC_DATE                      713 non-null int64
# PRIM_NO                       713 non-null int64
# PRIM_DESC                     385 non-null object
# SEC_NO                        713 non-null int64
# SEC_DESC                      385 non-null object
# AREA_HA                       713 non-null float64
# SHAPE_Leng                    713 non-null float64
# PERIM_M                       713 non-null float64
# ...

# %%
# make the new columns for LU08 using string indexing
df['prim_08'] = df['CODE_08'].str[0:1]
df['secon_08'] = df['CODE_08'].str[:2]
df['third_08'] = df['CODE_08'].str[0:3]
# make the new columns for LU16 using string indexing
df['prim_16'] = df['CODE_16'].str[0:1]
df['secon_16'] = df['CODE_16'].str[:2]
df['third_16'] = df['CODE_16'].str[0:3]

# %%
df.head()
# Out:
#    LU_CODE_16 LU_CODE LU_DESCRIP COMMOD_DES COMMENTS SRCE_SCALE  SRCE_DATE  \
# 0           0     NaN        NaN        NaN      NaN        NaN          0
# 1           0     NaN        NaN        NaN      NaN        NaN          0
# 2           0     NaN        NaN        NaN      NaN        NaN          0
# 3           0     NaN        NaN        NaN      NaN        NaN          0
# 4           0     NaN        NaN        NaN      NaN        NaN          0
#
#   SRCE_DATA  CONFIDENCE  LUC_DATE    ...     Shape_Length    Shape_Area  \
# 0       NaN           0         0    ...     97282.049314  4.599524e+06
# 1       NaN           0         0    ...     21949.027528  1.346029e+07
# 2       NaN           0         0    ...      8905.356723  2.500118e+06
# 3       NaN           0         0    ...     50683.895175  2.261812e+07
# 4       NaN           0         0    ...     12756.550434  8.466834e+06
#
#    CODE_08 CODE_16  prim_08  secon_08  third_08  prim_16  secon_16  third_16
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 713 entries, 0 to 712
# Data columns (total 43 columns):
# LU_CODE_16                    713 non-null int64
# LU_CODE                       385 non-null object
# LU_DESCRIP                    385 non-null object
# COMMOD_DES                    385 non-null object
# COMMENTS                      385 non-null object
# SRCE_SCALE                    385 non-null object
# SRCE_DATE                     713 non-null int64
# SRCE_DATA                     385 non-null object
# CONFIDENCE                    713 non-null int64
# LUC_DATE                      713 non-null int64
# PRIM_NO                       713 non-null int64
# PRIM_DESC                     385 non-null object
# SEC_NO                        713 non-null int64
# SEC_DESC                      385 non-null object
# AREA_HA                       713 non-null float64
# SHAPE_Leng                    713 non-null float64
# PERIM_M                       713 non-null float64
# ...

# %% [markdown]
# # Full amended data set

# %%
#8-16 change=df[['prim_08', 'secon_08', 'third_08', '08_AREA','prim_16', 'secon_16', 'third_16', 'COMMOD_DES','16_AREA']]

# %%
changefull=df[['prim_16', 'secon_16', 'third_16', 'COMMOD_DES', '16_AREA','prim_08', 'secon_08', 'third_08', '08_AREA']]

# %%
changefull
# Out:
#     prim_16 secon_16 third_16 COMMOD_DES        16_AREA prim_08 secon_08  \
# 0         0        0        0        NaN       0.000000       5       57
# 1         0        0        0        NaN       0.000000       2       21
# 2         0        0        0        NaN       0.000000       1       11
# 3         0        0        0        NaN       0.000000       1       11
# 4         0        0        0        NaN       0.000000       3       33
# 5         0        0        0        NaN       0.000000       2       21
# 6         0        0        0        NaN       0.000000       5       56
# 7         0        0        0        NaN       0.000000       1       12
# 8         0        0        0        NaN       0.000000       2       21
# 9         0        0        0        NaN       0.000000       2       21
# 10        0        0        0        NaN       0.000000       6       65
# 11        0        0        0        NaN       0.000000       1       11
# ...

# %% [markdown]
# ## Varriables year 2016

# %%
total16=df[['prim_16', 'secon_16', 'third_16', 'COMMOD_DES', '16_AREA']]

# %%
total16.head()
# Out:
#   prim_16 secon_16 third_16 COMMOD_DES  16_AREA
# 0       0        0        0        NaN      0.0
# 1       0        0        0        NaN      0.0
# 2       0        0        0        NaN      0.0
# 3       0        0        0        NaN      0.0
# 4       0        0        0        NaN      0.0

# %%
totalsecond08 = df[['secon_16', '16_AREA']]

# %%
totalsecond08.head()
# Out:
#   secon_16  16_AREA
# 0        0      0.0
# 1        0      0.0
# 2        0      0.0
# 3        0      0.0
# 4        0      0.0

# %% [markdown]
# ## Varriables year 2008

# %%
total08 = df[['prim_08', 'secon_08', 'third_08', '08_AREA']]

# %%
total08.head()
# Out:
#   prim_08 secon_08 third_08       08_AREA
# 0       5       57      572  4.599525e+06
# 1       2       21      210  1.346029e+07
# 2       1       11      113  2.500118e+06
# 3       1       11      113  2.261812e+07
# 4       3       33      333  8.466834e+06

# %%
totalsecond08 = df[['secon_08', '08_AREA']]

# %%
totalsecond08.head()
# Out:
#   secon_08       08_AREA
# 0       57  4.599525e+06
# 1       21  1.346029e+07
# 2       11  2.500118e+06
# 3       11  2.261812e+07
# 4       33  8.466834e+06

# %%
sumtotal08 = df.groupby(['secon_08'])['08_AREA'].sum
sumtotal08()
# Out:
# secon_08
# 11    2.543410e+07
# 12    2.289862e+07
# 13    3.357311e+08
# 21    6.781594e+07
# 32    3.443423e+05
# 33    8.466834e+06
# 36    1.305650e+07
# 44    8.933333e+06
# 45    3.383833e+06
# 46    2.084482e+06
# 52    9.484829e+03
# 54    1.307634e+07
# 55    5.256832e+04
# 56    9.602834e+02
# 57    3.303606e+07
# 62    1.038775e+04
# 65    1.013193e+06
# Name: 08_AREA, dtype: float64

# %%
type(sumtotal08)
# Out:
# list

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot()
# Out:
# []

# %%
import numpy as np
total08_2 = df.groupby(['secon_08']).agg({'08_AREA':np.sum})

# %%
print(total08_2)
# Out:
#                08_AREA
# secon_08
# 11        2.543410e+07
# 12        2.289862e+07
# 13        3.357311e+08
# 21        6.781594e+07
# 32        3.443423e+05
# 33        8.466834e+06
# 36        1.305650e+07
# 44        8.933333e+06
# 45        3.383833e+06
# 46        2.084482e+06
# 52        9.484829e+03
# 54        1.307634e+07
# 55        5.256832e+04
# 56        9.602834e+02
# 57        3.303606e+07
# 62        1.038775e+04
# 65        1.013193e+06

# %%
x = df['secon_08']
y = df ['08_AREA']
plt.plot(x, y)
plt.xlabel('Land use')
plt.ylabel('Area')
# Out:
# Text(0,0.5,'Area')

# %%
sumtotal08()
# Out:
# secon_08
# 11    2.543410e+07
# 12    2.289862e+07
# 13    3.357311e+08
# 21    6.781594e+07
# 32    3.443423e+05
# 33    8.466834e+06
# 36    1.305650e+07
# 44    8.933333e+06
# 45    3.383833e+06
# 46    2.084482e+06
# 52    9.484829e+03
# 54    1.307634e+07
# 55    5.256832e+04
# 56    9.602834e+02
# 57    3.303606e+07
# 62    1.038775e+04
# 65    1.013193e+06
# Name: 08_AREA, dtype: float64

# %%
a

x = df['secon_16']
y = df ['16_AREA']

plt.plot(x, y)
plt.xlabel('Land use')
plt.ylabel('Area')
# Out:
# Text(0,0.5,'Area')

# %%
marrakai168.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-77-7db6171cc375> in <module>()
# ----> 1 marrakai168.head()
#
# NameError: name 'marrakai168' is not defined

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 713 entries, 0 to 712
# Data columns (total 35 columns):
# LU_CODE_16                    713 non-null int64
# LU_CODE                       385 non-null object
# LU_DESCRIP                    385 non-null object
# COMMOD_DES                    385 non-null object
# COMMENTS                      385 non-null object
# SRCE_SCALE                    385 non-null object
# SRCE_DATE                     713 non-null int64
# SRCE_DATA                     385 non-null object
# CONFIDENCE                    713 non-null int64
# LUC_DATE                      713 non-null int64
# PRIM_NO                       713 non-null int64
# PRIM_DESC                     385 non-null object
# SEC_NO                        713 non-null int64
# SEC_DESC                      385 non-null object
# AREA_HA                       713 non-null float64
# SHAPE_Leng                    713 non-null float64
# PERIM_M                       713 non-null float64
# ...

# %%
marrakai168 = df.groupby(['LU_CODE_16', 'LU_CODE_08'])['08_AREA'].sum()

# %%
marrakai168.head()
# Out:
# LU_CODE_16  LU_CODE_08
# 0           113           2.513105e+07
#             116           3.030497e+05
#             125           2.289862e+07
#             130           2.796817e+04
#             133           9.705160e+07
# Name: 08_AREA, dtype: float64

# %%
marrakai168.describe()
# Out:
# count    5.700000e+01
# mean     9.392071e+06
# std      3.365001e+07
# min      9.602834e+02
# 25%      1.177415e+05
# 50%      1.013193e+06
# 75%      3.412648e+06
# max      2.338061e+08
# Name: 08_AREA, dtype: float64

# %%
marrakai168.head()
# Out:
# LU_CODE_16  LU_CODE_08
# 0           113           2.513105e+07
#             116           3.030497e+05
#             125           2.289862e+07
#             130           2.796817e+04
#             133           9.705160e+07
# Name: 08_AREA, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 713 entries, 0 to 712
# Data columns (total 35 columns):
# LU_CODE_16                    713 non-null int64
# LU_CODE                       385 non-null object
# LU_DESCRIP                    385 non-null object
# COMMOD_DES                    385 non-null object
# COMMENTS                      385 non-null object
# SRCE_SCALE                    385 non-null object
# SRCE_DATE                     713 non-null int64
# SRCE_DATA                     385 non-null object
# CONFIDENCE                    713 non-null int64
# LUC_DATE                      713 non-null int64
# PRIM_NO                       713 non-null int64
# PRIM_DESC                     385 non-null object
# SEC_NO                        713 non-null int64
# SEC_DESC                      385 non-null object
# AREA_HA                       713 non-null float64
# SHAPE_Leng                    713 non-null float64
# PERIM_M                       713 non-null float64
# ...

# %%
df['CODE_08'] = df['LU_CODE_08'].astype(str)
df['CODE_16'] = df['LU_CODE_16'].astype(str)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-95-aa41a07eba22> in <module>()
# ----> 1 df['CODE_08'] = df['LU_CODE_08'].astype(str)
#       2 df['CODE_16'] = df['LU_CODE_16'].astype(str)
#
# TypeError: list indices must be integers or slices, not str

# %%
# make the new columns for LU08 using string indexing
df['prim_08'] = df['LU_CODE_08'].str[0:1]
df['secon_08'] = df['LU_CODE_08'].str[:2]
df['third_08'] = df['LU_CODE_08'].str[0:3]
# make the new columns for LU16 using string indexing
df['prim_16'] = df['LU_CODE_16'].str[0:1]
df['secon_16'] = df['LU_CODE_16'].str[:2]
df['third_16'] = df['LU_CODE_16'].str[0:3]

# %%
df.head(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-93-6fae94b3c442> in <module>()
# ----> 1 df.head(10)
#
# AttributeError: 'list' object has no attribute 'head'

# %%
marrakai168.head()
# Out:
# LU_CODE_16  LU_CODE_08
# 0           113           2.513105e+07
#             116           3.030497e+05
#             125           2.289862e+07
#             130           2.796817e+04
#             133           9.705160e+07
# Name: 08_AREA, dtype: float64

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-91-41e0840687b6> in <module>()
# ----> 1 test.df
#
# NameError: name 'test' is not defined

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 713 entries, 0 to 712
# Data columns (total 43 columns):
# LU_CODE_16                    713 non-null object
# LU_CODE                       385 non-null object
# LU_DESCRIP                    385 non-null object
# COMMOD_DES                    385 non-null object
# COMMENTS                      385 non-null object
# SRCE_SCALE                    385 non-null object
# SRCE_DATE                     713 non-null int64
# SRCE_DATA                     385 non-null object
# CONFIDENCE                    713 non-null int64
# LUC_DATE                      713 non-null int64
# PRIM_NO                       713 non-null int64
# PRIM_DESC                     385 non-null object
# SEC_NO                        713 non-null int64
# SEC_DESC                      385 non-null object
# AREA_HA                       713 non-null float64
# SHAPE_Leng                    713 non-null float64
# PERIM_M                       713 non-null float64
# ...

# %%
# Removing columns
list_drop = ['LU_CODE_16', 'COMMOD', '16_AREA']
marraka08total.drop(list_drop, axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-87-ae3d30e8776d> in <module>()
#       1 # Removing columns
#       2 list_drop = ['LU_CODE_16', 'COMMOD', '16_AREA']
# ----> 3 df.drop(list_drop, axis=1, inplace=True)
#
# AttributeError: 'list' object has no attribute 'drop'

# %%
df.loc[:, 'prim_16':'secon_16']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-85-5bfa5c3c8420> in <module>()
# ----> 1 df.loc[:, 'prim_16':'secon_16']
#
# AttributeError: 'list' object has no attribute 'loc'

# %%
df1
# Out:
# [['prim_16', 'secon_16', 'third_16', 'COMMOD_DES']]

# %% [markdown]
# # Import files

# %%
marraka08total=pd.read_excel('../Land_Use/08-16_change_over_time_EDIT.xlsx')

# %%
marraka08total.head()
# Out:
#    LU_CODE_08  08_AREA  LU_CODE_16  COMMOD       16_AREA
# 0           0      0.0         652          1.370713e+06
# 1           0      0.0         210  cattle  1.158460e+07
# 2           0      0.0         652          1.427609e+05
# 3           0      0.0         113          3.356297e+04
# 4           0      0.0         652          7.526508e+05

# %%
# drop on ecolumn marraka08total.drop('COMMOD', axis=1, inplace=True)

# %%
# Removing columns
list_drop = ['LU_CODE_16', 'COMMOD', '16_AREA']
marraka08total.drop(list_drop, axis=1, inplace=True)

# %%
marraka08total.head()
# Out:
#    LU_CODE_08  08_AREA
# 0           0      0.0
# 1           0      0.0
# 2           0      0.0
# 3           0      0.0
# 4           0      0.0

# %%
marraka08total.groupby('LU_CODE_08')['08_AREA'].mean
# Out:
# <bound method GroupBy.mean of <pandas.core.groupby.SeriesGroupBy object at 0x000000000A29C080>>

# %%
marraka08total
# Out:
#      LU_CODE_08        08_AREA
# 0             0       0.000000
# 1             0       0.000000
# 2             0       0.000000
# 3             0       0.000000
# 4             0       0.000000
# 5             0       0.000000
# 6             0       0.000000
# 7             0       0.000000
# 8             0       0.000000
# 9             0       0.000000
# 10            0       0.000000
# 11            0       0.000000
# 12            0       0.000000
# 13            0       0.000000
# 14            0       0.000000
# 15            0       0.000000
# 16            0       0.000000
# 17            0       0.000000
# 18            0       0.000000
# 19            0       0.000000
# 20            0       0.000000
# 21            0       0.000000
# 22            0       0.000000
# 23            0       0.000000
# 24            0       0.000000
# 25            0       0.000000
# 26            0       0.000000
# 27            0       0.000000
# 28            0       0.000000
# ...

# %%
df=pd.read_excel('../Land_Use/08-16_change_over_time_EDIT.xlsx')

# %%
df.head()
# Out:
#    LU_CODE_08  08_AREA  LU_CODE_16  COMMOD       16_AREA
# 0           0      0.0         652          1.370713e+06
# 1           0      0.0         210  cattle  1.158460e+07
# 2           0      0.0         652          1.427609e+05
# 3           0      0.0         113          3.356297e+04
# 4           0      0.0         652          7.526508e+05

# %%
df[['LU_CODE_08', '08_AREA', 'LU_CODE_16', '16_AREA']]
# Out:
#      LU_CODE_08        08_AREA  LU_CODE_16       16_AREA
# 0             0       0.000000         652  1.370713e+06
# 1             0       0.000000         210  1.158460e+07
# 2             0       0.000000         652  1.427609e+05
# 3             0       0.000000         113  3.356297e+04
# 4             0       0.000000         652  7.526508e+05
# 5             0       0.000000         113  3.150583e+04
# 6             0       0.000000         572  4.843477e+06
# 7             0       0.000000         113  2.325471e+06
# 8             0       0.000000         113  1.077959e+07
# 9             0       0.000000         113  3.344450e+06
# 10            0       0.000000         113  2.952542e+04
# 11            0       0.000000         654  1.724599e+05
# 12            0       0.000000         210  3.514437e+05
# 13            0       0.000000         113  1.385681e+04
# 14            0       0.000000         210  1.934579e+06
# ...

# %%
df.to_excel('../Outputs/08_16_grouped2.xlsx')

# %%
los
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-700c13876399> in <module>()
# ----> 1 los
#
# NameError: name 'los' is not defined
