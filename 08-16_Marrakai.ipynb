# %%
import pandas as pd

# %%
from numpy import NaN, NAN, nan

# %%
import matplotlib
# %matplotlib inline

# %%
marr816 = pd.read_excel('../Land_Use/08-16_change_over_time_EDIT.xlsx')

# %%
marr816.head()
# Out:
#    LU_CODE_08  08_AREA  LU_CODE_16  COMMOD       16_AREA
# 0           0      0.0         652          1.370713e+06
# 1           0      0.0         210  cattle  1.158460e+07
# 2           0      0.0         652          1.427609e+05
# 3           0      0.0         113          3.356297e+04
# 4           0      0.0         652          7.526508e+05

# %%
marr816 =df.groupby(['LU_CODE_08', '08_AREA', 'LU_CODE_16', 'COMMOD'])['16_AREA'].sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-c0ebdbd36b62> in <module>()
#       1
# ----> 2 marr816 =df.groupby(['LU_CODE_08', '08_AREA', 'LU_CODE_16', 'COMMOD'])['16_AREA'].sum()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, **kwargs)
#    4414         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    4415                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 4416                        **kwargs)
#    4417
#    4418     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\groupby.py in groupby(obj, by, **kwds)
#    1697         raise TypeError('invalid type: %s' % type(obj))
#    1698
# ...

# %%
marr816
# Out:
# LU_CODE_08  08_AREA        LU_CODE_16  COMMOD
# 0           0.000000       113                                           2.115370e+07
#                            125                                           1.500568e+07
#                            133                                           1.236465e+07
#                            210         cattle                            1.156794e+08
#                            320                                           9.916301e+04
#                                        cattle                            1.296304e+06
#                                        goats                             7.666058e+04
#                                        horses                            6.989188e+04
#                                        pigs, goats, poultry & buffalo    7.090092e+04
#                            364                                           5.487598e+05
# ...

# %%
marr816.describe()
# Out:
# count    1.570000e+02
# mean     2.127335e+06
# std      9.821178e+06
# min      6.164839e+02
# 25%      1.895358e+04
# 50%      6.624864e+04
# 75%      2.772636e+05
# max      1.156794e+08
# Name: 16_AREA, dtype: float64

# %% [markdown]
# # Import files

# %%
marraka08total=pd.read_excel('../Land_Use/08-16_change_over_time_EDIT.xlsx')

# %%
marraka08total.head()
# Out:
#    LU_CODE_08  08_AREA  LU_CODE_16  COMMOD       16_AREA
# 0           0      0.0         652          1.370713e+06
# 1           0      0.0         210  cattle  1.158460e+07
# 2           0      0.0         652          1.427609e+05
# 3           0      0.0         113          3.356297e+04
# 4           0      0.0         652          7.526508e+05

# %%
# drop on ecolumn marraka08total.drop('COMMOD', axis=1, inplace=True)

# %%
# Removing columns
list_drop = ['LU_CODE_16', 'COMMOD', '16_AREA']
marraka08total.drop(list_drop, axis=1, inplace=True)

# %%
marraka08total.head()
# Out:
#    LU_CODE_08  08_AREA
# 0           0      0.0
# 1           0      0.0
# 2           0      0.0
# 3           0      0.0
# 4           0      0.0

# %%
marraka08total.groupby('LU_CODE_08')['08_AREA'].mean
# Out:
# <bound method GroupBy.mean of <pandas.core.groupby.SeriesGroupBy object at 0x000000000A29C080>>

# %%
marraka08total
# Out:
#      LU_CODE_08        08_AREA
# 0             0       0.000000
# 1             0       0.000000
# 2             0       0.000000
# 3             0       0.000000
# 4             0       0.000000
# 5             0       0.000000
# 6             0       0.000000
# 7             0       0.000000
# 8             0       0.000000
# 9             0       0.000000
# 10            0       0.000000
# 11            0       0.000000
# 12            0       0.000000
# 13            0       0.000000
# 14            0       0.000000
# 15            0       0.000000
# 16            0       0.000000
# 17            0       0.000000
# 18            0       0.000000
# 19            0       0.000000
# 20            0       0.000000
# 21            0       0.000000
# 22            0       0.000000
# 23            0       0.000000
# 24            0       0.000000
# 25            0       0.000000
# 26            0       0.000000
# 27            0       0.000000
# 28            0       0.000000
# ...

# %%
df=pd.read_excel('../Land_Use/08-16_change_over_time_EDIT.xlsx')

# %%
df.head()
# Out:
#    LU_CODE_08  08_AREA  LU_CODE_16  COMMOD       16_AREA
# 0           0      0.0         652          1.370713e+06
# 1           0      0.0         210  cattle  1.158460e+07
# 2           0      0.0         652          1.427609e+05
# 3           0      0.0         113          3.356297e+04
# 4           0      0.0         652          7.526508e+05

# %%
df[['LU_CODE_08', '08_AREA', 'LU_CODE_16', '16_AREA']]
# Out:
#      LU_CODE_08        08_AREA  LU_CODE_16       16_AREA
# 0             0       0.000000         652  1.370713e+06
# 1             0       0.000000         210  1.158460e+07
# 2             0       0.000000         652  1.427609e+05
# 3             0       0.000000         113  3.356297e+04
# 4             0       0.000000         652  7.526508e+05
# 5             0       0.000000         113  3.150583e+04
# 6             0       0.000000         572  4.843477e+06
# 7             0       0.000000         113  2.325471e+06
# 8             0       0.000000         113  1.077959e+07
# 9             0       0.000000         113  3.344450e+06
# 10            0       0.000000         113  2.952542e+04
# 11            0       0.000000         654  1.724599e+05
# 12            0       0.000000         210  3.514437e+05
# 13            0       0.000000         113  1.385681e+04
# 14            0       0.000000         210  1.934579e+06
# ...

# %%
df.to_excel('../Outputs/08_16_grouped2.xlsx')

# %%
los
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-700c13876399> in <module>()
# ----> 1 los
#
# NameError: name 'los' is not defined
